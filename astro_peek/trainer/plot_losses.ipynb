# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
file = pd.read_csv('/home/ssalhi/astro-ml-peek/shell/cifar10_experiment/epoch_losses.csv', sep=',')

losses = file["loss"]
epochs = file["epoch"]

# %%
plt.plot(epochs, losses)
plt.show()
